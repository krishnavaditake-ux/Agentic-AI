# %%
## text loader 

from langchain_community.document_loaders import TextLoader

loader=TextLoader('sample.txt')
loader
# Out:
# C:\Users\Krishna\AppData\Local\Temp\ipykernel_18452\1018242653.py:3: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader

# %%
text_loader=loader.load()
text_loader
# Out:
# [Document(metadata={'source': 'sample.txt'}, page_content='Good morning everyone,\n\nToday I would like to speak about the importance of hard work and determination. Success does not come overnight; it is achieved through consistent effort, discipline, and patience. Every challenge we face teaches us valuable lessons and helps us grow stronger. We should never be afraid of failure because it is a stepping stone to success. Setting clear goals, believing in ourselves, and working honestly can help us achieve our dreams. Let us stay positive, keep learning, and always give our best in everything we do. Thank you all for listening, and have a wonderful day.\n')]

# %% [markdown]
# pdf loader

# %%
from langchain_community.document_loaders import PyPDFLoader
loaders=PyPDFLoader('speech.pdf')
docs=loaders.load()
docs
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-07-06T14:36:59+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-07-06T14:36:59+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': 'speech.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Good morning everyone,\nToday I would like to speak about the importance of hard work and determination. Success does\nnot come overnight; it is achieved through consistent effort, discipline, and patience. Every\nchallenge we face teaches us valuable lessons and helps us grow stronger. We should never be\nafraid of failure because it is a stepping stone to success. Setting clear goals, believing in\nourselves, and working honestly can help us achieve our dreams. Let us stay positive, keep\nlearning, and always give our best in everything we do. Thank you all for listening, and have a\nwonderful day.')]

# %%
type(docs)
# Out:
# list

# %% [markdown]
# random number guess

# %%
import random

randomnumbe=random.randint(1,5)
#print(randomnumbe)

users_guess = int(input("enter your guess : "))

if users_guess==randomnumbe :
     print("correct guess")
     
else :
    print("wrong guess")

if users_guess>randomnumbe:
          print("your geess was higher")

if users_guess<randomnumbe:
      print("your guess is lower")
# Out:
# correct guess

# %% [markdown]
# WIKIPEDIA LOADER

# %%
from langchain_community.document_loaders import WikipediaLoader
docks2= WikipediaLoader(query="generative ai", load_max_docs=2).load()
print(docks2)
# Out:
# [Document(metadata={'title': 'Generative AI', 'summary': "Generative artificial intelligence (GenAI) is a subfield of artificial intelligence (AI) that uses generative models to generate text, images, videos, audio, software code (vibe coding) or other forms of data. These models learn the underlying patterns and structures of their training data, and use them to generate new data in response to input, which often takes the form of natural language prompts.\nThe prevalence of generative AI tools has increased significantly since the AI boom in the 2020s. This boom was made possible by improvements in deep neural networks, particularly large language models (LLMs), which are based on the transformer architecture. Generative AI applications include chatbots such as ChatGPT, Claude, Copilot, DeepSeek, Doubao, Google Gemini, Grok and Qwen; text-to-image models such as DALL-E, Firefly, Stable Diffusion, and Midjourney; and text-to-video models such as Veo, LTX and Sora.\nCompanies in a va
# ...
