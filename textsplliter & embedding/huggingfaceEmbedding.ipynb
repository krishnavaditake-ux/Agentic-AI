# %%
import os
from dotenv import load_dotenv
load_dotenv() #loads all env variables
# Out:
# True

# %%
os.environ['huggingfaceAPIkey']=os.getenv('huggingfaceAPIkey')
# token gets assigned to huggingfaceAPIkey

# %% [markdown]
# Sentence Transformers are pre-trained deep learning models that generate fixed-size vector embeddings for sentences or texts, enabling semantic similarity, semantic search, text clustering, classification, and information retrieval tasks

# %%
from langchain_huggingface import HuggingFaceEmbeddings
HuggingFaceEmbeddings(model='all')
